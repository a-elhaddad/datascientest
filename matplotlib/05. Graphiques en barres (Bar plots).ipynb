# %% [markdown]
# # Graphiques en barres (Bar plots)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# > La méthode `plt.bar` permet de tracer des diagrammes en barres, verticaux avec une seule ou plusieurs séries de valeurs : Pour afficher un bar plot il suffit d'entrer dans la méthode en premier argument les positions de début de chaque barre sur l'axe des $x$, et en second argument les hauteurs des barres.
# >
# > Les paramètres supplémentaires les plus importants sont la couleur à l'intérieur des barres (`color`) et la largeur relative de chaque barre (`width`, par défaut $0.8$, c'est-à-dire $20$% d'espace vide entre chaque barre).
# >
# > Exemple : Création d'un bar plot :
# >
# > `{plt.bar(range(4), [2, 3, 4, 5] , color = 'yellow', width = 0.6)`
# >
# > Comme toutes les fonctions de pyplot il existe beaucoup d'autres paramètres comme :
# - `edgecolor` : la couleur des encadrements.
# - `linewidth` : l'épaisseur des traits.
# - `yerr` : les valeurs des barres d'erreur.
# - `ecolor` : la couleur des barres d'erreur.
# - `orientation` : `horizontal` pour afficher un barplot horizontal.
# - `hatch` : les hachures. Valeurs possibles : `'/', '\', '|', '-', '+', 'x', 'o', 'O', '.', '*'`.
#
# - Créer un bar plot avec les abscisses de $0$ à $6$ et les hauteurs `[3,4,5,6,5,4,3]`, d'épaisseur $0.6$ et de couleur bleue.

# %%
plt.bar(range(7), [3,4,5,6,5,4,3], color='blue', width=0.6)
plt.show()

# %% [markdown]
# > Parmi tous les paramètres existants, `yerr` permet d'ajouter des barres d'erreurs aux barres du graphiques. Pour les ajouter il suffit d'entrer dans le paramètre `yerr` la taille des barres d'erreurs que l'on souhaite.
# >
# > `ecolor` permet de choisir la couleur de ces barres d'erreurs.
# >
# > Exemple : Utilisation des paramètres `yerr` et `ecolor` :
# >
# > `plt.bar(range(4), [2, 3, 4, 5] , color = 'yellow', width = 0.6, yerr=[1,2,0.5,2], ecolor='blue')`
#
# - Afficher le même bar plot que précédemment, avec des barres d'erreur de taille respectives `[0.5,2,1,3,2,0.5,1]`

# %%
plt.bar(range(7), [3,4,5,6,5,4,3], yerr=[0.5, 2, 1, 3, 2, 0.5, 1], color='blue', width=0.6)
plt.show()

# %% [markdown]
# > Il est possible d'afficher plusieurs diagrammes sur le même graphique, en faisant appel à autant de commandes `plt.bar` les unes à la suite des autres. Cependant, par défaut, la couleur sera la même, et il faut la modifier manuellement pour les différencier.
# >
# > Comme pour la méthode `plot` il est possible de donner un label à un plot bar en le précisant en argument, pour pourvoir afficher les légendes.
#
# - Créer un graphique affichant deux bar plot, un bleu et un vert, labellisés `Exemple 1` et `Exemple 2` avec pour arguments respectifs les listes `[1,3,5,7,9],[5,2,7,8,2]` et `[2,4,6,8,10],[8,6,2,5,6]`
# - Donner à l'axe des abscisses le label `Numéro`, et à l'axe des ordonnées le label `Hauteur`
# - Afficher les légendes et donner au graphique le titre `Mon graphique en barres`

# %%
plt.bar([1,3,5,7,9],  [5,2,7,8,2], color='blue', label='Exemple 1')
plt.bar([2,4,6,8,10], [8,6,2,5,6], color='green', label='Exemple 2')
plt.title('Mon graphique en barres')
plt.xlabel('Numéro')
plt.ylabel('Hauteur')
plt.legend()

plt.show()

# %% [markdown]
# > Il est possible, avec tout graphique, de modifier les graduations des axes grâce aux méthodes `xticks` et `yticks`.
# >
# > Exemple : Utilisation de la commande `xticks` :
# >
# >
# > La commande `plt.xticks([1,2,3], ['un', 'deux', 'trois'])` remplace les graduations de l'axe des abscisses par les trois graduations 'un', 'deux', 'trois'.
#
# - Créer une variable appelée `barWidth` qui vaut 0.4.
# - Créer une liste `x1` des chiffres de 0 à 7.
# - Créer une liste `x2` dont les éléments sont les éléments de `x1` additionnés de `barWidth`.
# - Créer les listes `y1` et `y2` suivantes: `[75, 95, 108, 128, 137, 158, 179, 204]` ; `[86, 99, 103, 136, 135, 146, 171, 215]`.
# - Créer dans la même figure deux bar plots (bleus et rouges), d'arguments respectifs `(x1, y1)` et `(x2, y2)`, et d'épaisseur `barWidth`.
# - Remplacer les graduations de l'axe des abscisses par `[A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']`

# %%
## Insérer votre code ici
barWidth = 0.4

x1 = np.arange(8)
x2 = x1+barWidth

y1 = [75, 95, 108, 128, 137, 158, 179, 204]
y2 = [86, 99, 103, 136, 135, 146, 171, 215]

plt.bar(x1, y1, color='blue', width=barWidth)
plt.bar(x2, y2, color='red', width=barWidth)

plt.xticks(x2, ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']);

plt.show()

# %% [markdown]
# > La palette de couleurs initiale de matplotlib étant réduite, il est possible d'utiliser des couleurs supplémentaires sous la forme d'un code couleur Color Hex.
# >
# > Il est également possible de créer un bar plot à partir de deux séries de valeurs, superposées l'une sur l'autre, en rajoutant le paramètre bottom au deuxième `plot.bar`.
# >
# > Exemple: `plt.bar(x , y1); plt.bar(x, y2, bottom = y1)` superpose la série `y2` sur `y1`.
#
# - Créer une variable appelée `barWidth` égale à 0.8.
# - Créer deux listes `y1` et `y2` contenant respectivement `[1, 2, 4, 3]` et `[3, 4, 4, 3]`.
# - Créer un bar plot de `y1` et lui donner en argument l'épaisseur `barWidth`, le code couleur `'#9999ff'`, un contour (`edgecolor`) bleu, le hachurage (`hatch`) `'/'`, et une épaisseur de ligne 3.
# - Afficher en superposition des barres créées à partir de `y2`, avec l'épaisseur `barWidth`, le code couleur `'#ff9999'`, un contour rouge, un style de ligne (`linestyle`) en pointillé (`'dotted'`) et une épaisseur de ligne 3.
# - Rajouter en abscisses les graduations `['A', 'B', 'C', 'D']` au milieu des barres

# %%
## Insérez votre code ici
barWidth = 0.8
y1 = [1, 2, 4, 3]
y2 = [3, 4, 4, 3]

plt.bar(range(len(y1)), y1, width=barWidth, color='#9999ff', edgecolor='blue', hatch='/', linewidth=3)
plt.bar(range(len(y1)), y2, bottom=y1, width=barWidth, color='#ff9999', edgecolor='red', linestyle='dotted', linewidth=3)
plt.xticks(range(len(y1)), ['A', 'B', 'C', 'D'])

plt.show()

# %% [markdown]
# > Pour afficher un bar plot horizontal, on utilise `barh`, en remplaçant `width` par `height` et `bottom` par `left`.
#
# - Afficher le même graphique que précédemment, mais en horizontal. (Note: Pas besoin de recréer les séries de valeurs)

# %%
## Insérez votre code ici
plt.barh(range(len(y1)), y1, height=barWidth, color='#9999ff', edgecolor='blue', hatch='/', linewidth=3)
plt.barh(range(len(y1)), y2, left=y1, height=barWidth, color='#ff9999', edgecolor='red', linestyle='dotted', linewidth=3)
plt.xticks(range(len(y1)), ['A', 'B', 'C', 'D'])

plt.show()

# %% [markdown]
# > Il est également possible d'afficher deux bar plots sur le même graphique en affichant un des deux en négatif.
#
# - Créer un tableau `X` d'entiers de 0 à 9.
# - Créer un tableau `Y1` dont les éléments  $y_i$  sont égaux à $(1-x_i/10)\times\alpha$, où les  $x_i$ sont les éléments de `X`, et $\alpha$ un nombre aléatoire entre 0.5 et 1.
# - Créer un second tableau `Y2` dont les éléments  $y_i$ sont égaux à $(1-x_i/10)\times\beta$, où les $x_i$ sont les éléments de `X`, et $\beta$ un nombre aléatoire entre 0.5 et 1.
# - Afficher le bar plot de `X` et `Y1`, avec la couleur `'#9999ff'` et un contour blanc.
# - Afficher le bar plot de `X` et `-Y2`, avec la couleur `'#ff9999'` et un contour blanc.
# - Rajouter sur le graphique les valeurs prises par `Y1` et `Y2`, respectivement au-dessus et en-dessous des barres.
# - Délimiter l'axe des ordonnées entre -1.25 et +1.25.

# %%
## Insérez votre code ici
X = np.arange(10)
Y1 = (1-X/10.)*np.random.uniform(0.5,1)
Y2 = (1-X/10.)*np.random.uniform(0.5,1)

plt.bar(X,  Y1, color='#9999ff', edgecolor='white')
plt.bar(X, -Y2, color='#ff9999', edgecolor='white')
plt.ylim(-1.25,1.25)

for x,y in enumerate(Y1):
    plt.text(x, y+0.1, s='%.2f' %y, ha='center', va='bottom')

for x,y in enumerate(Y2):
    plt.text(x, -y-0.1, s='%.2f' %y, ha='center', va='top')    
    
plt.show()
